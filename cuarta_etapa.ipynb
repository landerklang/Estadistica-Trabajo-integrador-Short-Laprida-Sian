# %%
import pandas as pd
import numpy as np

df=pd.read_excel("Short_Laprida_Sian_TPINTEGRADOR.xlsx",sheet_name="Hoja1",header=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 12 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unnamed: 0                                 0 non-null      float64
#  1   Unnamed: 1                                 0 non-null      float64
#  2   Genero                                     211 non-null    str
#  3   Edad                                       211 non-null    int64
#  4   Dispositivo                                211 non-null    str
#  5   Promedio diario de uso de pantalla         211 non-null    float64
#  6   Dia de mas uso                             211 non-null    str
#  7   Aplicación mas usada                       211 non-null    str
#  8   Promedio diario de desbloqueo de pantalla  211 non-null    object
#  9   Revisas el celular constante mente         211 non-null    str
#  10  Horas promedio en redes sociales           211 non-null    float64
#  11  Rendimiento academico                      211 non-null    int64
# dtypes: float64(4), int64(2), object(1), str(5)
# memory usage: 19.9+ KB

# %%
df=df.drop(columns={"Unnamed: 0","Unnamed: 1"})

# %%
df["Promedio diario de desbloqueo de pantalla"].unique()
# Out:
# array([65, 90, 40, 110, 30, 85, 55, 45, 120, 35, 60, 'muchos', 70, 25,
#        105, 58, 50, 'no se', 80, 130, 28, 62, 95, 38, 75, 22, 115, 42, 88,
#        32, 68, 52, 108, 36, 82, 64, 44, 140, 26, 66, 92, 39, 72, 20, 112,
#        54, 46, 84, 34, 56, 106, 78, 48, 125, 24, 69, 96, 33, 76, 23, 118,
#        57, 41, 86, 37, 71, 59, 109, 43, 81, 67, 49, 128, 27, 94, 74, 21,
#        114, 61, 83, 31, 73, 63, 111, 87, 51, 135, 29, 98, 117, 47, 89],
#       dtype=object)

# %%
df["Promedio diario de desbloqueo de pantalla"]=pd.to_numeric( df["Promedio diario de desbloqueo de pantalla"],errors="coerce")

# %%
df["Promedio diario de desbloqueo de pantalla"]=df["Promedio diario de desbloqueo de pantalla"].fillna(df["Promedio diario de desbloqueo de pantalla"].mean())

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 10 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Genero                                     211 non-null    str
#  1   Edad                                       211 non-null    int64
#  2   Dispositivo                                211 non-null    str
#  3   Promedio diario de uso de pantalla         211 non-null    float64
#  4   Dia de mas uso                             211 non-null    str
#  5   Aplicación mas usada                       211 non-null    str
#  6   Promedio diario de desbloqueo de pantalla  211 non-null    float64
#  7   Revisas el celular constante mente         211 non-null    str
#  8   Horas promedio en redes sociales           211 non-null    float64
#  9   Rendimiento academico                      211 non-null    int64
# dtypes: float64(3), int64(2), str(5)
# memory usage: 16.6 KB

# %%
df["Promedio diario de uso de pantalla"].unique()
# Out:
# array([ 6.5,  8.2,  4.5,  9. ,  3.5,  7.8,  6. ,  5.5, 10.2,  4. ,  6.8,
#         8.5,  5.2,  7.5,  3.8,  9.5,  6.2,  5. ,  8.8,  4.1,  7.2,  5.8,
#         9.2,  8.1, 10.5,  3.9,  6.9,  8.6,  4.8,  7.6,  3.6,  9.8,  6.4,
#         5.1,  8.9,  4.2,  7.4,  5.9,  9.4,  4.6,  8.3,  6.7,  5.4, 10.8,
#         3.7,  7.1,  8.7,  4.9,  3.4,  9.6,  6.1,  5.3,  8.4,  4.3,  9.1,
#         4.7,  8. ,  5.6, 10.1,  7.3,  4.4,  7.9,  9.9,  6.3,  9.3,  7. ,
#         5.7, 10.4,  9.7,  6.6,  7.7, 10.7])

# %%
bins=[0,2,4,6,8,10,12]
labels=["0-2","2-4","4-6","6-8","8-10","10-12"] 

df['Horas_intervalo'] = pd.cut(df['Promedio diario de uso de pantalla'], bins=bins, labels=labels, right=False)

# %%
df["Horas_intervalo"].head()
# Out:
# 0     6-8
# 1    8-10
# 2     4-6
# 3    8-10
# 4     2-4
# Name: Horas_intervalo, dtype: category
# Categories (6, str): ['0-2' < '2-4' < '4-6' < '6-8' < '8-10' < '10-12']

# %%
frecuencia_abs=df["Horas_intervalo"].value_counts().sort_index()

# %%
frecuencia_rel=(frecuencia_abs/len(df))*100
frecuencia_acum=frecuencia_abs.cumsum()
frecuencia_acum_rel=frecuencia_rel.cumsum()

# %%
tabla_frecuencia=pd.DataFrame({"Frecuencia absoluta":frecuencia_abs,
                            "Frecuencia relativa":frecuencia_rel,
                            "Frecuencia acumulada":frecuencia_acum,
                            "Frecuencia acumulada relativa":frecuencia_acum_rel})

print(tabla_frecuencia)
# Out:
#                  Frecuencia absoluta  Frecuencia relativa  \
# Horas_intervalo
# 0-2                                0             0.000000
# 2-4                               19             9.004739
# 4-6                               61            28.909953
# 6-8                               58            27.488152
# 8-10                              59            27.962085
# 10-12                             14             6.635071
#
#                  Frecuencia acumulada  Frecuencia acumulada relativa
# Horas_intervalo
# 0-2                                 0                       0.000000
# 2-4                                19                       9.004739
# 4-6                                80                      37.914692
# 6-8                               138                      65.402844
# 8-10                              197                      93.364929
# 10-12                             211                     100.000000

# %%
media=df["Promedio diario de uso de pantalla"].mean()
print("media:",media)
mediana=df["Promedio diario de uso de pantalla"].median()
print("mediana:",mediana)
moda=df["Promedio diario de uso de pantalla"].mode()[0]
print("moda:",moda)
varianza=df["Promedio diario de uso de pantalla"].var()
print("varianza:",varianza)
desviacion_estandar=df["Promedio diario de uso de pantalla"].std()
print("desviación estándar:",desviacion_estandar)
rango=df["Promedio diario de uso de pantalla"].max()-df["Promedio diario de uso de pantalla"].min()
print("rango:",rango)
# Out:
# media: 6.855450236966826
# mediana: 6.9
# moda: 3.9
# varianza: 4.172386820130896
# desviación estándar: 2.0426421174867846
# rango: 7.4

# %%
Q1=df["Promedio diario de uso de pantalla"].quantile(0.25)
print("Q1:",Q1)
Q3=df["Promedio diario de uso de pantalla"].quantile(0.75)
print("Q3:",Q3)
IQR=Q3-Q1  
print("IQR:",IQR)
# Out:
# Q1: 5.0
# Q3: 8.55
# IQR: 3.5500000000000007

# %%
if media>mediana:
    sesgo="positivo"
elif media<mediana:
    sesgo="negativo"
else:
    sesgo="simétrico"

print(sesgo)
# Out:
# negativo

# %%
###Interpretación de los resultados

print(f"la distribucion presenta un sesgo:{sesgo}")
print("la media y mediana indican que los datos estan distribuidos de manera desigual")
print("la desviacion estandar muestra que los datos se alejan de la media en promedio 2,042 unidades")
print(f"los datos se encuentran en un rango de {rango} unidades")
print(f"El {frecuencia_rel.max():.1f}% de los estudiantes se encuentra en el intervalo {tabla_frecuencia["Frecuencia relativa"].idxmax()} horas.")
print(f"El {frecuencia_acum_rel.iloc[-1]:.1f}% de los estudiantes usa entre 0 y 12 horas de redes sociales.")
# Out:
# la distribucion presenta un sesgo:negativo
# la media y mediana indican que los datos estan distribuidos de manera desigual
# la desviacion estandar muestra que los datos se alejan de la media en promedio 2,042 unidades
# los datos se encuentran en un rango de 7.4 unidades
# El 28.9% de los estudiantes se encuentra en el intervalo 4-6 horas.
# El 100.0% de los estudiantes usa entre 0 y 12 horas de redes sociales.
