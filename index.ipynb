# %%
import pandas as pd

# %%
df=pd.read_excel("Short_Laprida_Sian_TPINTEGRADOR.xlsx",sheet_name="Hoja1",header=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 12 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Unnamed: 0                                 0 non-null      float64
#  1   Unnamed: 1                                 0 non-null      float64
#  2   Genero                                     211 non-null    str
#  3   Edad                                       211 non-null    int64
#  4   Dispositivo                                211 non-null    str
#  5   Promedio diario de uso de pantalla         211 non-null    float64
#  6   Dia de mas uso                             211 non-null    str
#  7   Aplicación mas usada                       211 non-null    str
#  8   Promedio diario de desbloqueo de pantalla  211 non-null    object
#  9   Revisas el celular constante mente         211 non-null    str
#  10  Horas promedio en redes sociales           211 non-null    float64
#  11  Rendimiento academico                      211 non-null    int64
# dtypes: float64(4), int64(2), object(1), str(5)
# memory usage: 19.9+ KB

# %%
df=df.drop(columns={"Unnamed: 0","Unnamed: 1"})

# %%
df
# Out:
#         Genero  Edad Dispositivo  Promedio diario de uso de pantalla  \
# 0    Masculino    21     Android                                 6.5
# 1     Femenino    19     Android                                 8.2
# 2     Femenino    22      iPhone                                 4.5
# 3    Masculino    20     Android                                 9.0
# 4    Masculino    24     Android                                 3.5
# ..         ...   ...         ...                                 ...
# 206       Otro    21     Android                                 6.6
# 207   Femenino    20     Android                                 5.4
# 208  Masculino    22     Android                                 8.7
# 209  Masculino    24     Android                                 4.1
# 210   Femenino    19     Android                                 7.7
#
#     Dia de mas uso Aplicación mas usada  \
# 0           Sábado            Instagram
# 1          Domingo               TikTok
# 2           Martes             WhatsApp
# 3          Domingo               Juegos
# 4            Lunes             WhatsApp
# ..             ...                  ...
# 206         Sábado               TikTok
# 207         Jueves             WhatsApp
# 208        Domingo               TikTok
# 209      Miércoles             WhatsApp
# 210         Sábado            Instagram
#
#     Promedio diario de desbloqueo de pantalla  \
# 0                                          65
# 1                                          90
# 2                                          40
# 3                                         110
# 4                                          30
# ..                                        ...
# 206                                        61
# 207                                        45
# 208                                        83
# 209                                        31
# 210                                        73
#
#     Revisas el celular constante mente  Horas promedio en redes sociales  \
# 0                           Si, aveces                               4.0
# 1                         Si, a menudo                               6.0
# 2                             No mucho                               2.0
# 3                         Si, a menudo                               3.0
# 4                                Nunca                               1.0
# ..                                 ...                               ...
# 206                         Si, aveces                               4.1
# 207                           No mucho                               2.5
# 208                       Si, a menudo                               6.3
# 209                           No mucho                               1.5
# 210                         Si, aveces                               5.3
#
#      Rendimiento academico
# 0                        7
# 1                        6
# 2                        8
# 3                        5
# 4                        9
# ..                     ...
# 206                      8
# 207                      8
# 208                      6
# 209                      8
# 210                      7
#
# [211 rows x 10 columns]
