# %%
import pandas as pd

# %%
df=pd.read_excel("Short_Laprida_Sian_TPINTEGRADOR.xlsx",sheet_name="Hoja1",header=1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\short\Instituto\Matematica\Trabajo-integrador\env\Lib\site-packages\pandas\compat\_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1396     if level > 0:
#    1397         name = _resolve_name(name, package, level)
# -> 1398     return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
# ...

# %%
df.head()
# Out:
#                                                    Genero;Edad;Dispositivo;Promedio diario de uso de pantalla;Dia de mas uso;Aplicación mas usada;Promedio diario de desbloqueo de pantalla;Revisas el celular constante mente;Horas promedio en redes sociales;Rendimiento academico
# Masculino;21;Android;6.5;Sábado;Instagram;65;Si                                            aveces;4;7
# Femenino;19;Android;8.2;Domingo;TikTok;90;Si                                             a menudo;6;6
# Femenino;22;iPhone;4.5;Martes;WhatsApp;40;No mu...                                                NaN
# Masculino;20;Android;9;Domingo;Juegos;110;Si                                             a menudo;3;5
# Masculino;24;Android;3.5;Lunes;WhatsApp;30;Nunc...                                                NaN
